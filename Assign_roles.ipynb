# %% [markdown]
# **Razporedi študente v različne vloge v timu na vajah**
#
# 1. Določimo naključno število za *seed*
# 2. Prilagodimo seznam *students* glede na prisotnost na vajah
# 3. Prilagodimo *roles* glede na število študentov
# 4. Določimo razpored vlog
# 5. Shranimo razpored vlog za tekoči teden

# %%
# Template - ne spreminjaj

import random

# Step 1: Ask for the random seed
seed = 123456
random.seed(seed)

# Step 2: List of students and roles
students = ["Marija A.", 
            "Yaroslav G.", 
            "Eldar H.", 
            "Izidor J.", 
            "Dijana J.", 
            "Deni K.", 
            "Luka M.", 
            "Dajana T.", 
            "Lučka T.", 
            "Natalija Z."]
print("Students:", len(students))

# 1. Project Manager (PM) - Team leader
# 2. Business Analyst
# 3. UI/UX Designer
# 4. Developer (Frontend, Backend, Full stack)
# 5. QA Engineer (Quality Assurance)

roles = ["Project Manager", 
         "Business Analyst", 
         "Business Analyst", 
         "UI/UX Designer", 
         "Developer", 
         "Developer", 
         "Developer", 
         "Developer", 
         "Developer", 
         "QA Engineer"]
print("Roles:", len(roles))

# Step 3: Shuffle the roles list using the seed
random.shuffle(students)

# Step 4: Assign roles to students
assignments = dict(zip(students, roles))

# Step 5: Display the assignments
for student, role in assignments.items():
    i = True
    # print(f"* {role}: {student}")

# %% [markdown]
# **1. vaje 10. 10. 2024:**
#
# Seznam zadolžitev:

# %%
# Step 1: Ask for the random seed
seed = 0
random.seed(seed)

# Step 2: List of students and roles
students = ["Marija A.", 
            "Yaroslav G.", 
            "Eldar H.", 
            "Izidor J.", 
            "Dijana J.", 
            "Deni K.", 
            "Luka M.", 
            "Dajana T.", 
            "Lučka T.", 
            "Natalija Z."]
print("Students:", len(students))

# 1. Project Manager (PM) - Team leader
# 2. Business Analyst
# 3. UI/UX Designer
# 4. Developer (Frontend, Backend, Full stack)
# 5. QA Engineer (Quality Assurance)

roles = ["Project Manager", 
         "Business Analyst", 
         "Business Analyst", 
         "UI/UX Designer", 
         "Developer", 
         "Developer", 
         "Developer", 
         "Developer", 
         "Developer", 
         "QA Engineer"]
print("Roles:", len(roles))

# Step 3: Shuffle the roles list using the seed
random.shuffle(students)

# Step 4: Assign roles to students
assignments = dict(zip(students, roles))

# Step 5: Display the assignments
ind = 0
for student, role in assignments.items():
    ind = ind + 1
    print(f"{ind}. {role}: {student}")
